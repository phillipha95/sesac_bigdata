# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
tips = sns.load_dataset('tips')
tips[:10]
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2

# %%
tips.describe()

# %%
pd.DataFrame(tips['sex'].value_counts())

# %%
pd.DataFrame(tips['smoker'].value_counts())

# %%
pd.DataFrame(tips['time'].value_counts())

# %%
pd.DataFrame(tips.groupby('day')[['total_bill', 'tip']].sum())

# %%
pd.DataFrame(tips.groupby('day')[['total_bill', 'tip', 'size']].mean())

# %%
# pip install pandas_profiling

# %%
import pandas_profiling as pp
pp.ProfileReport(tips)

# %%
tips[:10]
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2

# %%
plt.figure(figsize=(8, 8)) 
sns.distplot(tips['total_bill'])
plt.grid()
plt.show()
# Out:
# C:\Users\phill\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(8, 8)) 
sns.distplot(tips['tip'])
plt.grid()
plt.show()
# Out:
# C:\Users\phill\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.relplot(x = "total_bill", y = "tip", data = tips);

# %%
plt.figure(figsize=(6, 6)) 
sns.countplot(x='day', data=tips)
plt.grid()
plt.show()

# %%
plt.figure(figsize=(3, 5)) 
sns.countplot(x='sex', palette=sns.color_palette('Set3'), data=tips)
plt.grid()
plt.show()

# %%
plt.figure(figsize=(8, 6)) 
sns.countplot(x='day',hue='sex', data=tips)
plt.grid()
plt.show()

# %%
plt.figure(figsize=(8, 6)) 
sns.countplot(x='size',hue='sex', palette=sns.color_palette('Set3'), data=tips)
plt.grid()
plt.show()

# %%
plt.figure(figsize=(8, 6)) 
sns.relplot(x = "total_bill", y = "tip", size = "size", sizes = (20,100), hue = "size", data = tips)
plt.grid()
plt.show()

# %%
plt.figure(figsize=(8, 6)) 
sns.catplot(x='day', y='tip', kind='swarm', data=tips)
plt.grid()
plt.show()
# Out:
# C:\Users\phill\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 8.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
plt.figure(figsize=(8, 6)) 
sns.swarmplot(x="day", y="total_bill", hue="sex", alpha=.75, data=tips);
plt.grid()
plt.show()

# %%
plt.figure(figsize=(8, 6)) 
sns.swarmplot(x="size", y="tip", hue='sex', data=tips);
plt.grid()
plt.show()
# Out:
# C:\Users\phill\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 25.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
plt.figure(figsize=(8, 6)) 
sns.boxplot(x = "day", y = "tip", data = tips)
plt.grid()
plt.show()

# %%
plt.figure(figsize=(10, 6)) 
sns.boxplot(x = "day", y = "total_bill", hue = "sex", data = tips)
plt.grid()
plt.show()
